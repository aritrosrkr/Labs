# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# **Assignment Part 1: Doubly Linked List**

# %% [markdown]
# For Assignment Part 1, you should write your full code in the following cells along with your driver codes on your own.

# %%
class Patient:
  def __init__(self, id = None, name = None, age = None, bloodgroup = None, next = None, prev = None):
    self.id = id
    self.name = name
    self.age = age
    self.bloodgroup= bloodgroup
    self.next = next
    self.prev = prev

# %%
class WRM:
  def __init__(self):
    self.head=Patient(None,None,None,None,None,None)
    self.head.next=self.head
    self.head.prev=self.head
    self.temp = self.head

  def registerPatient(self,id, name, age, bloodgroup):
    self.temp.next = Patient(id, name, age, bg, self.head, self.temp)
    self.temp = self.temp.next
    self.head.prev = self.temp

  def servePatient(self):
    if self.head.next is not self.head:
        print(f"Serving the Patient: {self.head.next.name}.")
        self.head.next = self.head.next.next
        self.head.next.prev = self.head
    else:
      print("!!! No Patient in Queue !!!")

  def showAllPatient(self):
    temp = self.head.next
    if temp is not self.head:
      print("Patients: | ", end = '')
      while temp is not self.head:
        print(temp.name, end = ' | ')
        temp = temp.next
    else:
      print("No patients in Queue")
    print()

  def canDoctorGoHome(self):
    if self.head.next is not None and self.head.next.name is not None:
      print("No, John Doctor cannot go home. There are patients in queue.")
    else:
      print("Yes, John Doctor can go home. There are no patients in queue.")

  def cancelAll(self):
    self.__init__()

  def ReverseTheLine(self):
    temp = self.head.next
    while temp is not self.head:
        nod = temp
        temp = temp.next
        prev = nod.prev
        nod.prev = nod.next
        nod.next = prev
    head_next = self.head.next
    self.head.next = self.head.prev
    self.head.prev = head_next

# %%
#Write a Tester Code in this cell
print("**Welcome to Waiting Room Management System**")
hospital = WRM()
while True:
    print()
    print("======== Select An Option ========")
    print('''| > 1. Register a Patient        |
| > 2. Serve Patient             |
| > 3. Show all Patients         |
| > 4. Can doctor go home?       |
| > 5. Cancel all appointments   |
| > 6. Reverse the queue         |
| > 7. Exit                      |''')
    print("==================================")
    x = int(input("Enter: "))
    print()
    if x == 1:
      print("------ Input Patient Detail ------")
      id =    input("  Enter ID   : ")
      invalid = False
      if not invalid:
        for i in id:
          if not '0'<=i<='9':
            print("!!! Unsuccessfull. Invalid ID !!!")
            invalid = True
      if not invalid:
        name =  input("  Enter Name : ")
        for i in name:
          if not (('A'<=i<='Z') or ('a'<=i<='z') or i==' '):
            print("!!! Unsuccessful. Invalid Name !!!")
            invalid = True
      if not invalid:
        age =   input("  Enter Age  : ")
        for i in age:
          if not '0'<=i<='9':
            print("!!! Unsuccessful. Invalid Age !!!")
            invalid = True
      if not invalid:
        groups = 'OAB+-'
        signs = '+-'
        bg =    input("  Enter Blood Group: ")
        for i in bg:
          if not (len(bg)>1 and i in groups):
            print(">>> Unsuccessful. Invalid Blood Group <<<")
            invalid = True
      if not invalid:
        hospital.registerPatient(id, name, age, bg)
        print(" >>> Registered Successfully <<<")
    elif x == 2:
      print("--- Serving next Patient in line ---")
      hospital.servePatient()
    elif x == 3:
      print("--- Showing all Patients in line ---")
      hospital.showAllPatient()
    elif x == 4:
      print("--- Checking if the doctor can go home ---")
      hospital.canDoctorGoHome()
    elif x == 5:
      hospital.cancelAll()
      print("--- Cancelled All Appointments ---")
    elif x == 6:
      hospital.ReverseTheLine()
      print("--- Reversed the Queue ---")
    elif x == 7:
      print("Exiting System...")
      break
    else:
      print("Invalid Input. Please select from given options.")
# Out:
# **Welcome to Waiting Room Management System**
#
# ======== Select An Option ========
# | > 1. Register a Patient        |
# | > 2. Serve Patient             |
# | > 3. Show all Patients         |
# | > 4. Can doctor go home?       |
# | > 5. Cancel all appointments   |
# | > 6. Reverse the queue         |
# | > 7. Exit                      |
# ...
# Enter: 1
#
# ------ Input Patient Detail ------
#   Enter ID   : 1
#   Enter Name : John Sekiro
#   Enter Age  : 21
#   Enter Blood Group: A+
#  >>> Registered Successfully <<<
#
# ======== Select An Option ========
# | > 1. Register a Patient        |
# | > 2. Serve Patient             |
# | > 3. Show all Patients         |
# | > 4. Can doctor go home?       |
# | > 5. Cancel all appointments   |
# | > 6. Reverse the queue         |
# | > 7. Exit                      |
# ...
# Enter: 1
#
# ------ Input Patient Detail ------
#   Enter ID   : 2
#   Enter Name : John Helldiver
#   Enter Age  : 21
#   Enter Blood Group: A+
# ...

# %% [markdown]
# **Assignment Part 2: Stack**
#
# Linked List based Stack is implemented in the following cell.

# %%
class Node:
  def __init__(self,elem=None,next=None):
    self.elem = elem
    self.next = next

class Stack:
  def __init__(self):
    self.__top = None

  def push(self,elem):
    nn = Node(elem,self.__top)
    self.__top = nn

  def pop(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    e = self.__top
    self.__top = self.__top.next
    return e.elem

  def peek(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    return self.__top.elem

  def isEmpty(self):
    return self.__top == None

# %%
#You can run this driver code cell to understand the methods of Stack class
st = Stack()
st.push(4)
st.push(3)
st.push(5)
st.push(1)
st.push(9)

print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print(st.isEmpty())
# Out:
# Peeked Element:  9
# Popped Element:  9
# Popped Element:  1
# Popped Element:  5
# Peeked Element:  3
# Popped Element:  3
# Popped Element:  4
# Peeked Element:  None
# Popped Element:  None
# True

# %% [markdown]
# You can print your stack using this code segment

# %%
def print_stack(st):
  if st.isEmpty():
    return
  p = st.pop()
  print('|',p,end=' ')
  # if p<10:
  #   print(' |')
  # else:
  print('|')
  #print('------')
  print_stack(st)
  st.push(p)

st = Stack()
st.push(4)
st.push(3)
st.push(5)
st.push(1)
st.push(9)
print_stack(st)
print('------')
# Out:
# | 9 |
# | 1 |
# | 5 |
# | 3 |
# | 4 |
# ------

# %% [markdown]
# Task 1: Diamond Count

# %%
def diamond_count(stack,string):
  count = 0
  for c in string:
    if c == ">":
      if stack.peek() == "<":
        stack.pop()
        count += 1
    elif c == "<":
        stack.push(c)
  return count



print('Test 01')
stack = Stack()
string = '<..><.<..>> '
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')


print('Test 02')
stack = Stack()
string = '<<<..<......<<<<....>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 1
unittest.output_test(returned_value, 1)
print('-----------------------------------------')


print('Test 03')
stack = Stack()
string = '>>><...<<..>>...>...>>>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')
# Out:
# Test 01
# Number of Diamonds: 3
# Accepted
# -----------------------------------------
# Test 02
# Number of Diamonds: 1
# Accepted
# -----------------------------------------
# Test 03
# Number of Diamonds: 3
# Accepted
# -----------------------------------------

# %% [markdown]
# Task 2: Tower of Blocks

# %%
def remove_block(stack, n):
  temp = Stack()
  for i in range(n):
    if i < n-1:
      temp.push(stack.pop())
    else:
      stack.pop()
  for i in range(n-1):
    stack.push(temp.pop())


print('Test 01')
st = Stack()
st.push(4)
st.push(19)
st.push(23)
st.push(17)
st.push(5)
print('Stack:')
print_stack(st)
print('------')
remove_block(st,2)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()

print('Test 02')
st = Stack()
st.push(73)
st.push(85)
st.push(15)
st.push(41)
print('Stack:')
print_stack(st)
print('------')
remove_block(st,3)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()
# Out:
# Test 01
# Stack:
# | 5 |
# | 17 |
# | 23 |
# | 19 |
# | 4 |
# ------
# After Removal
# | 5 |
# | 23 |
# | 19 |
# | 4 |
# ------
#
# ...
#
# Test 02
# Stack:
# | 41 |
# | 15 |
# | 85 |
# | 73 |
# ------
# After Removal
# | 41 |
# | 15 |
# | 73 |
# ------
#
# ...

# %% [markdown]
# Task 3: Stack Reverse

# %%
def conditional_reverse(stack):
  temp = Stack()
  while stack.peek() is not None:
    if temp.peek() != stack.peek():
      temp.push(stack.pop())
    else:
      stack.pop()
  return temp


print('Test 01')
st=Stack()
st.push(10)
st.push(10)
st.push(20)
st.push(20)
st.push(30)
st.push(10)
st.push(50)
print('Stack:')
print_stack(st)
print('------')
reversed_stack=conditional_reverse(st)
print('Conditional Reversed Stack:')
print_stack(reversed_stack) # This stack contains 50, 10, 30, 20, 10 in this order whereas top element should be 10
print('------')
# Out:
# Test 01
# Stack:
# | 50 |
# | 10 |
# | 30 |
# | 20 |
# | 20 |
# | 10 |
# | 10 |
# ------
# Conditional Reversed Stack:
# | 10 |
# | 20 |
# | 30 |
# | 10 |
# | 50 |
# ------
